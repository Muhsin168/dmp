# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhsin168/dmp/blob/main/Copy_of_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !if [ ! -d "mjlab" ]; then git clone -q https://github.com/Muhsin168/mjlab_test.git; fi
# %cd /content/mjlab
# !uv pip install --system -e . -q
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: '/content/mjlab'
# /content
# error: /content does not appear to be a Python project, as neither `pyproject.toml` nor `setup.py` are present in the directory

# %%
import os
from google.colab import userdata

os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')
os.environ['WANDB_ENTITY'] = userdata.get('WANDB_ENTITY')
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4951/1604146878.py in <cell line: 0>()
#       2 from google.colab import userdata
#       3
# ----> 4 os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')
#       5 os.environ['WANDB_ENTITY'] = userdata.get('WANDB_ENTITY')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret WANDB_API_KEY does not exist.

# %%
# !python -m mjlab.scripts.list_envs
# Out:
# +--------------------------------------------------------+
# |            Available Environments in Mjlab             |
# +---+----------------------------------------------------+
# | # | Task ID                                            |
# +---+----------------------------------------------------+
# | 1 | Mjlab-Lift-Cube-Yam                                |
# | 2 | Mjlab-Tracking-Flat-Unitree-G1                     |
# | 3 | Mjlab-Tracking-Flat-Unitree-G1-No-State-Estimation |
# | 4 | Mjlab-Velocity-Flat-Unitree-G1                     |
# | 5 | Mjlab-Velocity-Flat-Unitree-Go1                    |
# | 6 | Mjlab-Velocity-Flat-Unitree-Go1-ActuatorNet        |
# | 7 | Mjlab-Velocity-Rough-Unitree-G1                    |
# | 8 | Mjlab-Velocity-Rough-Unitree-Go1                   |
# +---+----------------------------------------------------+

# %%
# !python -m mjlab.scripts.train Mjlab-Velocity-Rough-Unitree-Go1 --env.scene.num-envs 4096
# Out:
# [INFO] Training with: device=cuda:0, seed=42, rank=0
# [INFO] Logging experiment in directory: logs/rsl_rl/go1_velocity/2025-12-09_05-16-58
# Setting seed: 42
# Warp 1.10.1 initialized:
#    CUDA Toolkit 12.8, Driver 12.4
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "Tesla T4" (15 GiB, sm_75, mempool enabled)
#    Kernel cache:
#      /root/.cache/warp/1.10.1
# Curriculum terrain generation took 0.4574 seconds.
# Module mujoco_warp._src.smooth 9ca7ec0 load on device 'cuda:0' took 7373.61 ms  (compiled)
